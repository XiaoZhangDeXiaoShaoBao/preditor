# %% [markdown]
# # lane_point 画图

# %% [markdown]
# ll{
#   lane_point {
#     position {
#       x: 587507.657434495
#       y: 4140637.1279831817
#     }
#     heading: -1.8651540853243604
#     width: 2.0833164936762283
#     relative_s: 0
#     relative_l: -2.6020493234306317
#     angle_diff: -0.16617151903207938
#   }
#   lane_point {
#     position {
#       x: 587507.10538014921
#       y: 4140635.2061283579
#     }
#     heading: -1.8333280335012196
#     width: 2.0848333837550204
#     relative_s: 2
#     relative_l: -2.6020493234306317
#     angle_diff: -0.19799757085521996
#   }
#   lane_point {
#     position {
#       x: 587506.56003935123
#       y: 4140633.2823710353
#     }
#     heading: -1.8693843028406574
#     width: 2.0741903780611883
#     relative_s: 4
#     relative_l: -2.6020493234306317
#     angle_diff: -0.16194130151578268
#   }
#   lane_point {
#     position {
#       x: 587506.00746868283
#       y: 4140631.3606774863
#     }
#     heading: -1.8303900868903269
#     width: 2.0545685861717038
#     relative_s: 6
#     relative_l: -2.6020493234306317
#     angle_diff: -0.20093551746611293
#   }
#   lane_point {
#     position {
#       x: 587505.462757553
#       y: 4140629.4367392082
#     }
#     heading: -1.8290804620623167
#     width: 2.0375887174682772
#     relative_s: 8
#     relative_l: -2.6020493234306317
#     angle_diff: -0.20224514229412316
#   }
#   lane_point {
#     position {
#       x: 587504.91804908111
#       y: 4140627.51278637
#     }
#     heading: -1.8715838441076571
#     width: 2.0277641302119869
#     relative_s: 10
#     relative_l: -2.6020493234306317
#     angle_diff: -0.15974176024878251
#   }
#   lane_point {
#     position {
#       x: 587504.37334598508
#       y: 4140625.5888459757
#     }
#     heading: -1.8703116107681235
#     width: 2.0218387148734389
#     relative_s: 12
#     relative_l: -2.6020493234306317
#     angle_diff: -0.16101399358831614
#   }
#   lane_point {
#     position {
#       x: 587503.82121867
#       y: 4140623.6670590336
#     }
#     heading: -1.8328618105616921
#     width: 2.0160468048611424
#     relative_s: 14
#     relative_l: -2.6020493234306317
#     angle_diff: -0.19846379379474755
#   }
#   lane_point {
#     position {
#       x: 587503.27676251216
#       y: 4140621.7430614177
#     }
#     heading: -1.8341650869037083
#     width: 2.0065548213078261
#     relative_s: 16
#     relative_l: -2.6020493234306317
#     angle_diff: -0.19716051745273155
#   }
#   lane_point {
#     position {
#       x: 587502.73257224518
#       y: 4140619.818953224
#     }
#     heading: -1.8366346122574846
#     width: 1.9968282432317135
#     relative_s: 18
#     relative_l: -2.6020493234306317
#     angle_diff: -0.19469099209895546
#   }
#   lane_point {
#     position {
#       x: 587502.18633253034
#       y: 4140617.895447772
#     }
#     heading: -1.8646829627150776
#     width: 2.0020975145908846
#     relative_s: 20
#     relative_l: -2.6020493234306317
#     angle_diff: -0.16664264164136222
#   }
#   lane_point {
#     position {
#       x: 587501.62644561159
#       y: 4140615.9758572588
#     }
#     heading: -1.8394076456336921
#     width: 2.0284891546542836
#     relative_s: 22
#     relative_l: -2.6020493234306317
#     angle_diff: -0.19191795872274753
#   }
#   lane_point {
#     position {
#       x: 587501.07089459116
#       y: 4140614.0550211719
#     }
#     heading: -1.8616583257388952
#     width: 2.0613812820078539
#     relative_s: 24
#     relative_l: -2.6020493234306317
#     angle_diff: -0.1696672786175446
#   }
#   lane_point {
#     position {
#       x: 587500.51713318308
#       y: 4140612.133670982
#     }
#     heading: -1.8605279972208792
#     width: 2.0893667028389542
#     relative_s: 26
#     relative_l: -2.6020493234306317
#     angle_diff: -0.1707976071355608
#   }
#   lane_point {
#     position {
#       x: 587499.958118204
#       y: 4140610.2138415105
#     }
#     heading: -1.8439440867575874
#     width: 2.1154502463218066
#     relative_s: 28
#     relative_l: -2.6020493234306317
#     angle_diff: -0.18738151759885247
#   }
#   lane_point {
#     position {
#       x: 587499.40457657352
#       y: 4140608.2924419288
#     }
#     heading: -1.8450632798146067
#     width: 2.1431115306952879
#     relative_s: 30
#     relative_l: -2.6020493234306317
#     angle_diff: -0.18626232454183311
#   }
#   lane_point {
#     position {
#       x: 587498.84822089737
#       y: 4140606.3718321552
#     }
#     heading: -1.856142924238108
#     width: 2.1700681244607876
#     relative_s: 32
#     relative_l: -2.6020493234306317
#     angle_diff: -0.17518268011833182
#   }
#   lane_point {
#     position {
#       x: 587498.28971483221
#       y: 4140604.4518492878
#     }
#     heading: -1.8480504305832595
#     width: 2.1944622159220355
#     relative_s: 34
#     relative_l: -2.6020493234306317
#     angle_diff: -0.18327517377318037
#   }
#   lane_point {
#     position {
#       x: 587497.73221465526
#       y: 4140602.5315837464
#     }
#     heading: -1.8535669143328151
#     width: 2.2207799018462033
#     relative_s: 36
#     relative_l: -2.6020493234306317
#     angle_diff: -0.17775869002362477
#   }
#   lane_point {
#     position {
#       x: 587497.16545097751
#       y: 4140600.6139814942
#     }
#     heading: -1.8506816377152702
#     width: 2.2519445918893748
#     relative_s: 38
#     relative_l: -2.6020493234306317
#     angle_diff: -0.18064396664116966
#   }
#  }
#   total_length: 83.272283339480637
# }

# %%
import sys
import matplotlib.pyplot as plt
x=[]
y=[]
fb = open('./a.txt','r')
lines=fb.readlines()
try: 
    for line in lines:
        ｌine1=line.strip()
        if line1.startswith('x') :# 变量初始化
            line2=line1.split()[1]
            x.append(line2)
                        
        if line1.startswith('y'):
            line3=line1.split()[1]
            y.append(line3)                      
finally:
     fb.close()
#print(x)
#print(y) 
print(len(x))
print(len(y))

'''
##打印地图中的数据
x1=[]
y1=[]
fb1 = open('./map.txt','r')
lines1=fb1.readlines()
try: 
    for line in lines1:
        ｌine1=line.strip()
        if line1.startswith('x') :# 变量初始化
            line2=line1.split()[1]
            #print(line2)
            x1.append(line2)
                        
        if line1.startswith('y'):
            line3=line1.split()[1]
            #print(line3)
            y1.append(line3)                      
finally:
     fb.close()
        

#plt.plot(x1, y1, color="b",  linewidth=1.0, label='map')

print(len(x1))
print(len(y1))
'''
data = list(map(eval, ｘ))
#results = list(map(int, results))
#print(x)
#print(data)
plt.plot(x, y, color="r",  marker="*", linewidth=1.0, label='lanep_point')
plt.legend()
plt.show()
# Out:
# 20
# 20
# ['587507.657434495', '587507.10538014921', '587506.56003935123', '587506.00746868283', '587505.462757553', '587504.91804908111', '587504.37334598508', '587503.82121867', '587503.27676251216', '587502.73257224518', '587502.18633253034', '587501.62644561159', '587501.07089459116', '587500.51713318308', '587499.958118204', '587499.40457657352', '587498.84822089737', '587498.28971483221', '587497.73221465526', '587497.16545097751']
# [587507.657434495, 587507.1053801492, 587506.5600393512, 587506.0074686828, 587505.462757553, 587504.9180490811, 587504.3733459851, 587503.82121867, 587503.2767625122, 587502.7325722452, 587502.1863325303, 587501.6264456116, 587501.0708945912, 587500.5171331831, 587499.958118204, 587499.4045765735, 587498.8482208974, 587498.2897148322, 587497.7322146553, 587497.1654509775]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1.2, 2.5, 4.5, 7.3]

print(x)
print(y)
plt.plot(x, y, color="r", linestyle="--", marker="*", linewidth=1.0)

plt.show()
# Out:
# [1, 2, 3, 4]
# [1.2, 2.5, 4.5, 7.3]

# %%
import sys
import matplotlib.pyplot as plt
import re

HDx=[]
HDy=[]
Sx=[]
Sy=[]
fb = open('./finalpoint.txt','r')
lines=fb.readlines()
#print(lines)
try: 
    for line in lines:
        #print(line)
        t1=re.findall(r'(\(0\):\d+)',line)#匹配(0):587510 
        #print(t1)
        if len(t1)>0:
            line1=int(t1[0].split(':')[-1])
            Sx.append(line1)
            #print(line1)
            #print(type(line1))
        t2=re.findall(r'(\(1\):\d*\.\d+)',line)#匹配(1):587510 
        if len(t2)>0:
            line2=int(float(t2[0].split(':')[-1])*1000000)
            Sy.append(line2)
            #print(line2)
           # print(type(line2))
        t3=re.findall(r'(x\(\):\d+)',line)#匹配hdmap_point.x():587508 
        if len(t3)>0:
            line3=int(t3[0].split(':')[-1])
            HDx.append(line3)
            #print(line3)
        #print(type(line3))
        t4=re.findall(r'(y\(\):\d+\.\d+)',line)#匹配hdmap_point.y():4.14064e+06
        if len(t4)>0:
            line4=int(float(t4[0].split(':')[-1])*1000000)
            HDy.append(line4)
            #print(line4)
            #print(type(line4))
finally:
     fb.close()
#print(Sx)
#print(Sy) 
print(len(Sx))
print(len(Sy))
print(len(HDx))
print(len(HDy))
x1=[]
y1=[]
fb1 = open('./map.txt','r')
lines1=fb1.readlines()
try: 
    for line in lines1:
        ｌine1=line.strip()
        if line1.startswith('x') :# 变量初始化
            line2=line1.split()[1]
            #print(line2)
            x1.append(line2)
                        
        if line1.startswith('y'):
            line3=line1.split()[1]
            #print(line3)
            y1.append(line3)                      
finally:
     fb.close()
     
ｘ1 = list(map(eval, ｘ1))
y1 = list(map(eval, y1))
#plt.plot(x1, y1, color="b", marker=".", label='Oringin_map')
#plt.legend()
#plt.show()
plt.plot(HDx, HDy, color="r",  marker=">", linewidth=1.0, label='HD_map')
plt.plot(Sx, Sy, color="g",  marker="*", linewidth=1.0, label='Smooth')
plt.legend()
plt.show()
print(Sx)
print(Sy)
# Out:
# 80
# 80
# 80
# 80
# [587510, 587510, 587510, 587509, 587509, 587509, 587509, 587508, 587508, 587508, 587507, 587507, 587507, 587507, 587506, 587506, 587506, 587506, 587505, 587505, 587505, 587505, 587504, 587504, 587504, 587503, 587503, 587503, 587503, 587502, 587502, 587502, 587502, 587501, 587501, 587501, 587501, 587500, 587500, 587500, 587499, 587499, 587499, 587499, 587498, 587498, 587498, 587498, 587497, 587497, 587497, 587496, 587496, 587496, 587496, 587495, 587495, 587495, 587495, 587494, 587494, 587494, 587494, 587493, 587493, 587493, 587492, 587492, 587492, 587492, 587491, 587491, 587491, 587491, 587491, 587490, 587490, 587490, 587490, 587489]
# ...
